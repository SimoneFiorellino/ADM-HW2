# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import functions as mod

# %%
def read_both_datasets():
    oct_dataset = pd.read_csv('2019-Oct.csv', header='infer',
                      parse_dates = ['event_time'],
                      date_parser=pd.to_datetime,
                     nrows=2000000)
    nov_dataset = pd.read_csv('2019-Nov.csv', header='infer',
                      parse_dates = ['event_time'],
                      date_parser=pd.to_datetime,
                     nrows=2000000)
    frames = [oct_dataset, nov_dataset]
    dataset = pd.concat(frames)
    dataset = dataset.reset_index()
    return dataset

# %%
dataset = read_both_datasets()

# %%
mod.request_five(dataset)
# Out:
# In what part of the day is your store most visited? 8 o'clock
# Number of views: 289950

# %%
mod.request_six(dataset)
# Out:
# Find the overall conversion rate of your store:
# Overall conversion rate: 0.017
# Category: conversion rate
#
# accessories: 0.027
# medicine: 0.023
# appliances: 0.014
# computers: 0.011
# kids: 0.011
# country_yard: 0.011
# construction: 0.01
# auto: 0.009
# electronics: 0.006
# stationery: 0.006
# apparel: 0.005
# sport: 0.005
# furniture: 0.004

# %%
mod.request_seven(dataset)
# Out:
# Most of the business, around 65%, likely comes from about 20% of customers
