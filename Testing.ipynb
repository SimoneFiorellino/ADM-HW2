# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import functions as mod

# %%
def read_both_datasets():
    oct_dataset = pd.read_csv('2019-Oct.csv', header='infer',
                      parse_dates = ['event_time'],
                      date_parser=pd.to_datetime)
    nov_dataset = pd.read_csv('2019-Nov.csv', header='infer',
                      parse_dates = ['event_time'],
                      date_parser=pd.to_datetime,
                     nrows=2000000)
    frames = [oct_dataset, nov_dataset]
    dataset = pd.concat(frames)
    dataset = dataset.reset_index()
    return dataset

# %%
dataset = read_both_datasets()

# %%
mod.request_five(dataset)
# Out:
# In what part of the day is your store most visited? 16 o'clock
# Number of views: 3074784

# %%
mod.request_six(dataset)
# Out:
# Find the overall conversion rate of your store:
# Overall conversion rate: 0.018

# %%
mod.request_seven(dataset)
# Out:
# Most of your business, around 72%, likely comes from about 20% of your customers
